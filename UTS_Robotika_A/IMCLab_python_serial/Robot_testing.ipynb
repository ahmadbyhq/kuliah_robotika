# %%
import serial as s
port = "COM4"
baudrate = 115200
ser = s.Serial(port, baudrate, timeout=1)
print(f"Terhubung ke {port} pada {baudrate} baudrate.")
# Out:
# Terhubung ke COM4 pada 115200 baudrate.

# %%
import serial as s
port = "COM4"
baudrate = 115200
ser = s.Serial(port, baudrate, timeout=1)
ser.close()
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Cell In[1], line 4
#       2 port = "COM4"
#       3 baudrate = 115200
# ----> 4 ser = s.Serial(port, baudrate, timeout=1)
#       5 ser.close()
#
# File c:\Users\baiha\AppData\Local\Programs\Python\Python310\lib\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      31 self._overlapped_read = None
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# File c:\Users\baiha\AppData\Local\Programs\Python\Python310\lib\site-packages\serial\serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File c:\Users\baiha\AppData\Local\Programs\Python\Python310\lib\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      62 if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#      67     self._overlapped_read = win32.OVERLAPPED()
#
# SerialException: could not open port 'COM4': PermissionError(13, 'Access is denied.', None, 5)

# %%
import keyboard
import serial as s
port = "COM4"
baudrate = 115200

try:
    ser = s.Serial(port, baudrate, timeout=1)
    print(f"Terhubung ke {port} pada {baudrate} baudrate.")
except Exception as e:
    print(f"Gagal membuka port {port}: {e}")
    exit()

print("Tekan '1' untuk RUN (kirim '1')")
print("Tekan '0' untuk STOP (kirim '0')")
print("Tekan 'q' untuk keluar")

while True:
    cmd = input("Input [1/0/q]: ").strip()
    if cmd == '1':
        ser.write(b'1')
        print("Kirim: 1 (RUN)")
    elif cmd == '0':
        ser.write(b'0')
        print("Kirim: 0 (STOP)")
    elif cmd.lower() == 'q':
        print("Keluar dari program.")
        break
        ser.close()        
    else:
        print("Perintah tidak dikenal. Masukkan '1', '0', atau 'q'.")
# Out:
# Gagal membuka port COM4: could not open port 'COM4': PermissionError(13, 'Access is denied.', None, 5)
# Tekan '1' untuk RUN (kirim '1')
# Tekan '0' untuk STOP (kirim '0')
# Tekan 'q' untuk keluar
# Kirim: 1 (RUN)
# Kirim: 0 (STOP)
# Keluar dari program.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import keyboard
import serial as s
port = "COM4"
baudrate = 115200

try:
    ser = s.Serial(port, baudrate, timeout=1)
    print(f"Terhubung ke {port} pada {baudrate} baudrate.")
except Exception as e:
    print(f"Gagal membuka port {port}: {e}")
    exit()

print("Tekan '1' untuk RUN (kirim '1')")
print("Tekan '0' untuk STOP (kirim '0')")
print("Tekan 'q' untuk keluar")

while True:
    cmd = input("Input [1/2/3/4/0/q]: ").strip()
    if cmd == '1':
        ser.write(b'1')
        print("Kirim: 1 (FOWARD)")
    if cmd == '2':
        ser.write(b'2')
        print("Kirim: 2 (TURN RIGHT)")
    if cmd == '3':
        ser.write(b'3')
        print("Kirim: 3 (TURN LEFT)")
    if cmd == '4':
        ser.write(b'4')
        print("Kirim: 4 (BACKWARD)")
    elif cmd == '0':
        ser.write(b'0')
        print("Kirim: 0 (STOP)")
    elif cmd.lower() == 'q':
        print("Keluar dari program.")
        break
        ser.close()        
    else:
        print("Perintah tidak dikenal. Masukkan '1','2','3','4', '0', atau 'q'.")
# Out:
# Gagal membuka port COM4: could not open port 'COM4': PermissionError(13, 'Access is denied.', None, 5)
# Tekan '1' untuk RUN (kirim '1')
# Tekan '0' untuk STOP (kirim '0')
# Tekan 'q' untuk keluar
# Kirim: 1 (FOWARD)
# Perintah tidak dikenal. Masukkan '1','2','3','4', '0', atau 'q'.
# Kirim: 2 (TURN RIGHT)
# Perintah tidak dikenal. Masukkan '1','2','3','4', '0', atau 'q'.
# Kirim: 3 (TURN LEFT)
# Perintah tidak dikenal. Masukkan '1','2','3','4', '0', atau 'q'.
# Kirim: 4 (BACKWARD)
# Kirim: 0 (STOP)
# Kirim: 1 (FOWARD)
# Perintah tidak dikenal. Masukkan '1','2','3','4', '0', atau 'q'.
# Kirim: 0 (STOP)
# Perintah tidak dikenal. Masukkan '1','2','3','4', '0', atau 'q'.
# Keluar dari program.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
